# %%
import matplotlib.pyplot as plt
subject_avg = df[subjects].mean()

subject_avg.plot(kind='bar', color=['red','blue','green','black','purple'])

plt.title('Average Marks by Subject')
plt.xlabel('Subjects')
plt.ylabel('Average Marks')
plt.show()

# %%
import matplotlib.pyplot as plt
subject_avg = df[subjects].mean()

subject_avg.plot(kind='bar')

plt.title('Average Marks by Subject')
plt.xlabel('Subjects')
plt.ylabel('Average Marks')
plt.show()

# %%
def grade(avg):
  if avg >=90:
   return'A+'
  elif avg >=80:
   return'A'
  elif avg >=70:
   return'B'
  elif avg >=60:
   return'C'
  elif avg >=50:
   return'D'
  else:
   return'F'
df['Grade'] = df['Average'].apply(grade)
df[['Student_Name','Average','Grade']].tail(7)
# Out:
#      Student_Name  Average Grade
# 993   Student_994     61.6     C
# 994   Student_995     74.6     B
# 995   Student_996     83.0     A
# 996   Student_997     70.8     B
# 997   Student_998     62.0     C
# 998   Student_999     60.6     C
# 999  Student_1000     60.8     C

# %%
subjects = ['Maths' , 'Science' , 'English' , 'Computer' , 'Social']
df['Average'] = df[subjects].mean(axis=1)
df[['Student_Name' , 'Average']].head(7)
# Out:
#   Student_Name  Average
# 0    Student_1     57.2
# 1    Student_2     52.0
# 2    Student_3     64.6
# 3    Student_4     63.0
# 4    Student_5     68.4
# 5    Student_6     67.0
# 6    Student_7     62.2

# %%
subjects = ['Maths' , 'Science' , 'English' , 'Computer' , 'Social']
df['Total']= df[subjects].sum(axis=1)
df[['Student_Name' , 'Total']].head()
# Out:
#   Student_Name  Total
# 0    Student_1    286
# 1    Student_2    260
# 2    Student_3    323
# 3    Student_4    315
# 4    Student_5    342

# %%
df['Total_marks'] = df['Maths'] + df['Science'] + df['English'] + df['Computer'] + df['Social']
df.head()
# Out:
#   Student_ID Student_Name Class  Maths  Science  English  Computer  Social  \
# 0      S0001    Student_1     B     49       38       70        66      63
# 1      S0002    Student_2     A     48       46       89        39      38
# 2      S0003    Student_3     D     62       64       99        38      60
# 3      S0004    Student_4     D     63       92       70        35      55
# 4      S0005    Student_5     A     78       70       54        62      78
#
#    Average Grade Result  Total_marks
# 0     57.2     D   Pass          286
# 1     52.0     D   Pass          260
# 2     64.6     C   Pass          323
# 3     63.0     C   Pass          315
# 4     68.4     C   Pass          342

# %%
df.isnull().sum()
# Out:
# Student_ID      0
# Student_Name    0
# Class           0
# Maths           0
# Science         0
# English         0
# Computer        0
# Social          0
# Average         0
# Grade           0
# Result          0
# dtype: int64

# %%
df.describe()
# Out:
#              Maths      Science      English     Computer       Social  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     67.803000    67.118000    68.965000    67.303000    66.917000
# std      18.555714    18.930886    18.992538    19.097379    19.185051
# min      35.000000    35.000000    35.000000    35.000000    35.000000
# 25%      52.000000    50.000000    53.000000    51.000000    50.000000
# 50%      68.000000    67.000000    69.000000    67.000000    66.000000
# 75%      84.000000    83.000000    85.000000    84.000000    84.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#            Average
# count  1000.000000
# mean     67.621200
# std       8.538814
# min      43.200000
# 25%      61.600000
# 50%      67.400000
# 75%      73.400000
# max      94.200000

# %%
df['Average'].mean()
# Out:
# np.float64(67.62120000000002)

# %%
df.info(8)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_ID    1000 non-null   object
#  1   Student_Name  1000 non-null   object
#  2   Class         1000 non-null   object
#  3   Maths         1000 non-null   int64
#  4   Science       1000 non-null   int64
#  5   English       1000 non-null   int64
#  6   Computer      1000 non-null   int64
#  7   Social        1000 non-null   int64
#  8   Average       1000 non-null   float64
#  9   Grade         1000 non-null   object
#  10  Result        1000 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 86.1+ KB

# %%
df.tail(8)
# Out:
#     Student_ID  Student_Name Class  Maths  Science  English  Computer  Social  \
# 992      S0993   Student_993     C     61       39       75        79      53
# 993      S0994   Student_994     D     92       55       73        50      38
# 994      S0995   Student_995     A     98       53       93        75      54
# 995      S0996   Student_996     B     99       77       72        95      72
# 996      S0997   Student_997     B     91       78       49        96      40
# 997      S0998   Student_998     D     49       74       38        86      63
# 998      S0999   Student_999     B     80       46       76        42      59
# 999      S1000  Student_1000     A     70       60       37        45      92
#
#      Average Grade Result
# 992     61.4     C   Pass
# 993     61.6     C   Pass
# 994     74.6     B   Pass
# 995     83.0     A   Pass
# 996     70.8     B   Pass
# 997     62.0     C   Pass
# 998     60.6     C   Pass
# 999     60.8     C   Pass

# %%
import pandas as pd

df=pd.read_csv(file_path)
df.head(8)
# Out:
#   Student_ID Student_Name Class  Maths  Science  English  Computer  Social  \
# 0      S0001    Student_1     B     49       38       70        66      63
# 1      S0002    Student_2     A     48       46       89        39      38
# 2      S0003    Student_3     D     62       64       99        38      60
# 3      S0004    Student_4     D     63       92       70        35      55
# 4      S0005    Student_5     A     78       70       54        62      78
# 5      S0006    Student_6     C     46       83       47        80      79
# 6      S0007    Student_7     C     40       93       50        83      45
# 7      S0008    Student_8     C     81       59       43        40      64
#
#    Average Grade Result
# 0     57.2     D   Pass
# 1     52.0     D   Pass
# 2     64.6     C   Pass
# 3     63.0     C   Pass
# 4     68.4     C   Pass
# 5     67.0     C   Pass
# 6     62.2     C   Pass
# 7     57.4     D   Pass

# %%
from google.colab import drive, files
import os
import pandas as pd

drive.mount('/content/drive')

dataset_path = "/content/drive/MyDrive/datasets"
os.makedirs(dataset_path, exist_ok=True)

uploaded = files.upload()

filename = list(uploaded.keys())[0]
file_path = os.path.join(dataset_path, filename)

# Removed os.rename due to Invalid cross-device link error.
# Instead, write the uploaded file content directly to the target path.
with open(file_path, 'wb') as f:
    f.write(uploaded[filename])

# Read file safely
if filename.endswith('.csv'):
    df = pd.read_csv(file_path)
elif filename.endswith('.xlsx'):
    df = pd.read_excel(file_path)
else:
    print("Unsupported file format")

df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      <input type="file" id="files-2f098214-2c45-40e2-9b43-9ff03457d4d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f098214-2c45-40e2-9b43-9ff03457d4d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
